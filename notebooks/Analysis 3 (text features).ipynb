# %%
from utils_all import *
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.manifold import TSNE
import seaborn as sns
# %matplotlib inline
import inspect
from sklearn.decomposition import IncrementalPCA
from sklearn import manifold
# Out:
# /Users/jetbrains/miniconda3/envs/py35/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# %store -r data

# %%
data_cl = clean_df(data)

# %%
len(list(filter(lambda x: x,data_cl.text.isnull())))
# Out:
# 675

# %%
data_cl.shape
# Out:
# (6140, 297)

# %% [markdown]
# First of all, let's create several obviouse features:
# - len of the text
# - number of punctuation
# - number of digits
# - #numbers/len
# - number of upper case
#
# Links: https://www.quora.com/Natural-Language-Processing-What-are-the-possible-features-that-can-be-extracted-from-text

# %%
import re
import string

# %%
data_cl['text_str'] = data_cl.text.apply(str).replace('nan','')

# %%
data_cl['text_len'] = data_cl.text_str.apply(len)

# %%
count = lambda l1, l2: len(list(filter(lambda c: c in l2, l1)))

# %%
data_cl['num_punctuation'] = data_cl.text_str.apply(lambda x: count(x, string.punctuation))

# %%
data_cl['num_digits'] = data_cl.text_str.apply(lambda x: count(x, string.digits))

# %%
data_cl['digits_share'] = data_cl.num_digits/data_cl.text_len

# %%
data_cl['num_upper'] = data_cl.text_str.apply(lambda x: count(x, string.ascii_uppercase))

# %%
data_cl['num_space'] = data_cl.text_str.apply(lambda x: count(x, string.whitespace))

# %%
data_cl
# Out:
#                                                    url    meta_name  \
# 0    http://www.therapeutenfinder.com/veranstaltung...  description
# 1    http://www.therapeutenfinder.com/veranstaltung...    startDate
# 2    http://www.therapeutenfinder.com/veranstaltung...     location
# 3    http://www.ticketbis.com/jp/morrisey-%E3%83%8B...         name
# 4    http://www.ticketbis.com/jp/morrisey-%E3%83%8B...    startDate
# 5    http://www.ticketbis.com/jp/morrisey-%E3%83%8B...     location
# 7    http://www.volksfeste-in-deutschland.de/doelke...         name
# 8    http://www.volksfeste-in-deutschland.de/doelke...  description
# 10   http://www.volksfeste-in-deutschland.de/doelke...     location
# 12                 https://bxl.demosphere.eu/rv/3412\n     location
# 14                 https://bxl.demosphere.eu/rv/3412\n  description
# 15   http://www.chicagoparkdistrict.com/parks/Galew...         name
# 16   http://www.chicagoparkdistrict.com/parks/Galew...    startDate
# 17   http://www.chicagoparkdistrict.com/parks/Galew...     location
# 18   http://www.chicagoparkdistrict.com/parks/Galew...  description
# 19   http://www.chicagoparkdistrict.com/parks/Bosle...         name
# 20   http://www.chicagoparkdistrict.com/parks/Bosle...    startDate
# 23   http://www.chicagoparkdistrict.com/parks/Bosle...     location
# 24   http://www.elbe-wochenblatt.de/eissendorf/loka...         name
# 25   http://www.elbe-wochenblatt.de/eissendorf/loka...     location
# 26   http://www.elbe-wochenblatt.de/eissendorf/loka...  description
# 27   http://www.elbe-wochenblatt.de/kirchdorf/lokal...         name
# 29   http://www.elbe-wochenblatt.de/kirchdorf/lokal...     location
# 30   http://www.elbe-wochenblatt.de/kirchdorf/lokal...  description
# 31   http://metroo.es/e/torrejon/luis-mariano-el-pr...  description
# 32   http://metroo.es/e/torrejon/luis-mariano-el-pr...    startDate
# 34   http://metroo.es/e/torrejon/luis-mariano-el-pr...     location
# 37   https://www.finesettimana.it/Scoprire/Dettagli...     location
# 38   https://www.finesettimana.it/Scoprire/Dettagli...  description
# 41   https://www.finesettimana.it/Scoprire/Dettagli...     location
# ..                                                 ...          ...
# 545  http://www.southwestorlandobulletin.com/?optio...     location
# 546  http://www.southwestorlandobulletin.com/?optio...  description
# 547  http://www.southwestorlandobulletin.com/?optio...         name
# 548  http://www.southwestorlandobulletin.com/?optio...    startDate
# 549  http://www.southwestorlandobulletin.com/?optio...     location
# 550  http://www.southwestorlandobulletin.com/?optio...  description
# 551  http://www.reservix.de/tickets-cuba-insel-im-a...         name
# 552  http://www.reservix.de/tickets-cuba-insel-im-a...    startDate
# 553  http://www.reservix.de/tickets-cuba-insel-im-a...     location
# 554  http://www.reservix.de/tickets-cuba-insel-im-a...  description
# 1    http://www.shreveportla.gov/Calendar.aspx?EID=...     location
# 2    http://www.shreveportla.gov/Calendar.aspx?EID=...         name
# 3    http://www.shreveportla.gov/Calendar.aspx?EID=...         name
# 4    http://www.shreveportla.gov/Calendar.aspx?EID=...  description
# 5    http://www.southwestorlandobulletin.com/?optio...         name
# 6    http://www.southwestorlandobulletin.com/?optio...    startDate
# 7    http://www.southwestorlandobulletin.com/?optio...     location
# 8    http://www.southwestorlandobulletin.com/?optio...  description
# 9    http://www.southwestorlandobulletin.com/?optio...         name
# 10   http://www.southwestorlandobulletin.com/?optio...    startDate
# 11   http://www.southwestorlandobulletin.com/?optio...     location
# 12   http://www.southwestorlandobulletin.com/?optio...  description
# 13   http://www.southwestorlandobulletin.com/?optio...         name
# 14   http://www.southwestorlandobulletin.com/?optio...    startDate
# 15   http://www.southwestorlandobulletin.com/?optio...     location
# 16   http://www.southwestorlandobulletin.com/?optio...  description
# 17   http://www.therapeutenfinder.com/veranstaltung...         name
# 18   http://www.therapeutenfinder.com/veranstaltung...  description
# 19   http://www.therapeutenfinder.com/veranstaltung...    startDate
# 20   http://www.therapeutenfinder.com/veranstaltung...     location
#
#                                                   text x_coords y_coords  \
# 0    Ein Sonntag in jedem 2. Monat ab 18 Uhr\r\rFür...       52      653
# 1                                           12.07.2015      142     1528
# 2               Ort:\rWürzstr. 1\r \r\r81371 \rMünchen       57     1573
# 3                             Morrissey (モリッシー) Dallas       26      851
# 4                           2017. 4. 15 -      土 20:00       26      865
# 5    Majestic Theatre Dallas,          Dallas,     ...       26      882
# 7          Dölker Mühlenfest in Viersen OT Dülken 2017       10      365
# 8    Das Mühlenfest in Viersen OT Dülken hält hält ...       10      425
# 10   Alter Markt om Ortsteil Dülken\r\r41751\r Viersen       15     1164
# 12   Lieu :BruxellesIHECSRue de l'Etuve 58-601000 B...      616      174
# 14   Ciné-Débat : Louise Michel - L'autogestion ici...       20      230
# 15               Movie Inside the Park at Mayfair Park       15      200
# 16                                                 NaN       15      313
# 17   Mayfair Park\r\r \r\r                        4...       15      313
# 18   We've moved the movies inside for our spring m...       15      543
# 19   45th Annual Special Olympics Spring Games & Op...       15      200
# 20                                                 NaN       15      358
# 23   Eckersall Playground Park\r\r \r\r            ...       15      358
# 24   VAN WOLFEN – ERDIGER BLUESROCK ! SUPPORT : WIR...       30      371
# 25   Marias Ballroom, Lassallestraße 11, 21073 Hamb...      109      585
# 26   VAN WOLFEN :Und der hat im Laufe der Zeit reic...       30      632
# 27                          Puppen entern Heimatmuseum       30      489
# 29   Museum der Elbinsel, Kirchdorfer Straße 163, 2...      109      557
# 30   Wenn Erika Harenkamp mit ihren wunderschönen, ...       30      693
# 31   Género/Subgénero: Teatro/Musical. Compañía: FE...        6      491
# 32                                                 NaN      721      677
# 34            Dirección :      Torrejón de ArdozMadrid      721      677
# 37                                                 NaN       15      794
# 38   VENDREDI 20 JUIN 2014 dès 23H30le Moth Club pr...       15      794
# 41                                                 NaN       15      748
# ..                                                 ...      ...      ...
# 545  Oakland Nature Preserve747 Machete Trail, Oakl...      312     7239
# 546  Oakland Nature Preserve sponsors a two- to thr...      312     8510
# 547                                         Kayak Tour      312     6691
# 548                                    8:30 AM-3:00 PM      318     6859
# 549  Oakland Nature Preserve747 Machete Trail, Oakl...      312     7239
# 550  Oakland Nature Preserve sponsors a two- to thr...      312     8510
# 551          Tickets - Karten Cuba - Insel im Aufbruch      555      292
# 552                           So, 19.03.2017 11:00 Uhr      555      377
# 553  Linden-Museum StuttgartHegelplatz 1, 70174 Stu...      555      393
# 554  Das sozialistische Kuba befindet sich im Wande...      555      439
# 1    Location:\r\r\rView Facility\r\r\rSouthern Hil...      594      718
# 2                                         318-673-7818       56      657
# 3    Southern Hills Community Center Park Advisory ...       56      657
# 4                                                  NaN       56      785
# 5                                           Kayak Tour      312     6691
# 6                                      8:30 AM-3:00 PM      318     6859
# 7    Oakland Nature Preserve747 Machete Trail, Oakl...      312     7239
# 8    Oakland Nature Preserve sponsors a two- to thr...      312     8510
# 9                                           Kayak Tour      312     6691
# 10                                     8:30 AM-3:00 PM      318     6859
# 11   Oakland Nature Preserve747 Machete Trail, Oakl...      312     7239
# 12   Oakland Nature Preserve sponsors a two- to thr...      312     8510
# 13                                          Kayak Tour      312     6691
# 14                                     8:30 AM-3:00 PM      318     6859
# 15   Oakland Nature Preserve747 Machete Trail, Oakl...      312     7239
# 16   Oakland Nature Preserve sponsors a two- to thr...      312     8510
# 17                 Neu! Psycho-Holistischer Stammtisch       52      586
# 18   Ein Sonntag in jedem 2. Monat ab 18 Uhr\r\rFür...       52      653
# 19                                          12.07.2015      142     1528
# 20              Ort:\rWürzstr. 1\r \r\r81371 \rMünchen       57     1505
#
#     block_height block_width     tag num_child num_siblings    ...     \
# 0            636         288     div       NaN            4    ...
# 1             15          64    span       NaN            1    ...
# 2             45         278      li       NaN            6    ...
# 3             14         157    span       NaN            1    ...
# 4             17         160    time       NaN            4    ...
# 5             26         160     div       NaN            4    ...
# 7             55         380      h1       NaN            8    ...
# 8            286         380       p       NaN            8    ...
# 10            46         370     div       NaN            1    ...
# 12           250         362     div       NaN            5    ...
# 14           657         576     div       NaN            5    ...
# 15            60         357    span       NaN            2    ...
# 16             0           0    time       NaN           22    ...
# 17           100         370       p       NaN           22    ...
# 18           240         370    span       NaN           22    ...
# 19            88         327    span       NaN            2    ...
# 20             0           0    time       NaN           29    ...
# 23           100         370       p       NaN           29    ...
# 24            55         607    span       NaN            1    ...
# 25            14         280    span       NaN            4    ...
# 26           985         628    span       NaN            2    ...
# 27            27         353    span       NaN            1    ...
# 29            14         332    span       NaN            4    ...
# 30           529         629    span       NaN            3    ...
# 31           308         620    span       NaN            5    ...
# 32             0           0    time       NaN            9    ...
# 34            28         230     div       NaN            9    ...
# 37             0           0    span       NaN            8    ...
# 38           910         370     div       NaN            1    ...
# 41             0           0    span       NaN            8    ...
# ..           ...         ...     ...       ...          ...    ...
# 545         1266          26     div       NaN            5    ...
# 546         6422           6     div       NaN            5    ...
# 547          162           6      h5       NaN            2    ...
# 548          198          37    span       NaN            1    ...
# 549         1266          26     div       NaN            5    ...
# 550         6422           6     div       NaN            5    ...
# 551           34         385      h1       NaN           18    ...
# 552           12         133    time       NaN            1    ...
# 553           28         156  strong       NaN            3    ...
# 554          208         385       p       NaN           18    ...
# 1             94         350     div       NaN            5    ...
# 2             59         538    span       NaN            3    ...
# 3             59         538    span       NaN            3    ...
# 4              0           0    span       NaN            4    ...
# 5            162           6      h5       NaN            2    ...
# 6            198          37    span       NaN            1    ...
# 7           1266          26     div       NaN            5    ...
# 8           6422           6     div       NaN            5    ...
# 9            162           6      h5       NaN            2    ...
# 10           198          37    span       NaN            1    ...
# 11          1266          26     div       NaN            5    ...
# 12          6422           6     div       NaN            5    ...
# 13           162           6      h5       NaN            2    ...
# 14           198          37    span       NaN            1    ...
# 15          1266          26     div       NaN            5    ...
# 16          6422           6     div       NaN            5    ...
# 17            52         288      h1       NaN            4    ...
# 18           636         288     div       NaN            4    ...
# 19            15          64    span       NaN            1    ...
# 20            45         278      li       NaN            6    ...
#
#     max-height       stroke-width buffered-rendering  \
# 0         auto             normal            stretch
# 1         auto             normal            stretch
# 2         auto             normal            stretch
# 3         auto             normal            stretch
# 4         auto             normal            stretch
# 5         auto             normal            stretch
# 7         auto             normal            stretch
# 8         auto             normal            stretch
# 10        auto             normal            stretch
# 12        auto             normal            stretch
# 14        auto             normal            stretch
# 15        auto             normal            stretch
# 16        auto             normal            stretch
# 17        auto             normal            stretch
# 18        auto             normal            stretch
# 19        auto             normal            stretch
# 20        auto             normal            stretch
# 23        auto             normal            stretch
# 24        auto             normal            stretch
# 25        auto             normal            stretch
# 26        auto             normal            stretch
# 27        auto             normal            stretch
# 29        auto             normal            stretch
# 30        auto             normal            stretch
# 31        auto             normal            stretch
# 32        auto             normal            stretch
# 34        auto             normal            stretch
# 37        auto             normal            stretch
# 38        auto             normal            stretch
# 41        auto             normal            stretch
# ..         ...                ...                ...
# 545          1                  1               auto
# 546          1                  1               auto
# 547          1                  1               auto
# 548          1                  1               auto
# 549          1                  1               auto
# 550          1                  1               auto
# 551          1                  1               auto
# 552          1                  1               auto
# 553          1                  1               auto
# 554          1                  1               auto
# 1        slice         175px 47px               left
# 2        slice  138.328125px 18px               left
# 3        slice  138.328125px 18px               left
# 4        slice            0px 0px               left
# 5        slice          3px 234px              right
# 6        slice   18.828125px 99px              right
# 7        slice       13px 408.5px              right
# 8        slice         3px 3229px              right
# 9        slice          3px 234px              right
# 10       slice   18.828125px 99px              right
# 11       slice       13px 408.5px              right
# 12       slice         3px 3229px              right
# 13       slice          3px 234px              right
# 14       slice   18.828125px 99px              right
# 15       slice       13px 408.5px              right
# 16       slice         3px 3229px              right
# 17       slice         144px 26px              start
# 18       slice        144px 318px              start
# 19       slice            0px 0px               left
# 20       slice       139px 22.5px               left
#
#                                               text_str text_len  \
# 0    Ein Sonntag in jedem 2. Monat ab 18 Uhr\r\rFür...      681
# 1                                           12.07.2015       10
# 2               Ort:\rWürzstr. 1\r \r\r81371 \rMünchen       33
# 3                             Morrissey (モリッシー) Dallas       24
# 4                           2017. 4. 15 -      土 20:00       26
# 5    Majestic Theatre Dallas,          Dallas,     ...       66
# 7          Dölker Mühlenfest in Viersen OT Dülken 2017       43
# 8    Das Mühlenfest in Viersen OT Dülken hält hält ...      608
# 10   Alter Markt om Ortsteil Dülken\r\r41751\r Viersen       46
# 12   Lieu :BruxellesIHECSRue de l'Etuve 58-601000 B...       73
# 14   Ciné-Débat : Louise Michel - L'autogestion ici...     1318
# 15               Movie Inside the Park at Mayfair Park       37
# 16                                                            0
# 17   Mayfair Park\r\r \r\r                        4...      156
# 18   We've moved the movies inside for our spring m...      527
# 19   45th Annual Special Olympics Spring Games & Op...       62
# 20                                                            0
# 23   Eckersall Playground Park\r\r \r\r            ...      163
# 24   VAN WOLFEN – ERDIGER BLUESROCK ! SUPPORT : WIR...       80
# 25   Marias Ballroom, Lassallestraße 11, 21073 Hamb...       52
# 26   VAN WOLFEN :Und der hat im Laufe der Zeit reic...     2669
# 27                          Puppen entern Heimatmuseum       26
# 29   Museum der Elbinsel, Kirchdorfer Straße 163, 2...       61
# 30   Wenn Erika Harenkamp mit ihren wunderschönen, ...     2091
# 31   Género/Subgénero: Teatro/Musical. Compañía: FE...     1089
# 32                                                            0
# 34            Dirección :      Torrejón de ArdozMadrid       40
# 37                                                            0
# 38   VENDREDI 20 JUIN 2014 dès 23H30le Moth Club pr...     1721
# 41                                                            0
# ..                                                 ...      ...
# 545  Oakland Nature Preserve747 Machete Trail, Oakl...      113
# 546  Oakland Nature Preserve sponsors a two- to thr...      412
# 547                                         Kayak Tour       10
# 548                                    8:30 AM-3:00 PM       15
# 549  Oakland Nature Preserve747 Machete Trail, Oakl...      113
# 550  Oakland Nature Preserve sponsors a two- to thr...      412
# 551          Tickets - Karten Cuba - Insel im Aufbruch       41
# 552                           So, 19.03.2017 11:00 Uhr       24
# 553  Linden-Museum StuttgartHegelplatz 1, 70174 Stu...       52
# 554  Das sozialistische Kuba befindet sich im Wande...      887
# 1    Location:\r\r\rView Facility\r\r\rSouthern Hil...      121
# 2                                         318-673-7818       12
# 3    Southern Hills Community Center Park Advisory ...       61
# 4                                                             0
# 5                                           Kayak Tour       10
# 6                                      8:30 AM-3:00 PM       15
# 7    Oakland Nature Preserve747 Machete Trail, Oakl...      113
# 8    Oakland Nature Preserve sponsors a two- to thr...      412
# 9                                           Kayak Tour       10
# 10                                     8:30 AM-3:00 PM       15
# 11   Oakland Nature Preserve747 Machete Trail, Oakl...      113
# 12   Oakland Nature Preserve sponsors a two- to thr...      412
# 13                                          Kayak Tour       10
# 14                                     8:30 AM-3:00 PM       15
# 15   Oakland Nature Preserve747 Machete Trail, Oakl...      113
# 16   Oakland Nature Preserve sponsors a two- to thr...      412
# 17                 Neu! Psycho-Holistischer Stammtisch       35
# 18   Ein Sonntag in jedem 2. Monat ab 18 Uhr\r\rFür...      681
# 19                                          12.07.2015       10
# 20              Ort:\rWürzstr. 1\r \r\r81371 \rMünchen       33
#
#     num_punctuation num_digits digits_share num_upper num_space
# 0                16         16     0.023495        45        94
# 1                 2          8     0.800000         0         0
# 2                 2          6     0.181818         3         7
# 3                 2          0     0.000000         2         2
# 4                 4         11     0.423077         0        10
# 5                 2          0     0.000000         4        30
# 7                 0          4     0.093023         6         6
# 8                 9          0     0.000000        35        93
# 10                0          5     0.108696         5         8
# 12                3         10     0.136986        10         9
# 14               36          6     0.004552        55       217
# 15                0          0     0.000000         5         6
# 16                0          0          NaN         0         0
# 17                6         19     0.121795         7        92
# 18               18          3     0.005693        15        94
# 19                1          2     0.032258         7         8
# 20                0          0          NaN         0         0
# 23                6         21     0.128834         7        93
# 24                2          0     0.000000        62        13
# 25                2          7     0.134615         6         6
# 26               66         16     0.005995       184       382
# 27                0          0     0.000000         2         2
# 29                2          8     0.131148         7         8
# 30               50         22     0.010521       104       295
# 31               50          2     0.001837       242       163
# 32                0          0          NaN         0         0
# 34                1          0     0.000000         4         9
# 37                0          0          NaN         0         0
# 38              305         74     0.042998       230       184
# 41                0          0          NaN         0         0
# ..              ...        ...          ...       ...       ...
# 545               6          6     0.053097        17        14
# 546              16         13     0.031553        23        56
# 547               0          0     0.000000         2         1
# 548               3          6     0.400000         4         2
# 549               6          6     0.053097        17        14
# 550              16         13     0.031553        23        56
# 551               2          0     0.000000         5         7
# 552               4         12     0.500000         2         3
# 553               2          6     0.115385         5         4
# 554              20          2     0.002255        56       122
# 1                 4          9     0.074380        15        24
# 2                 2         10     0.833333         0         0
# 3                 0          0     0.000000         8         7
# 4                 0          0          NaN         0         0
# 5                 0          0     0.000000         2         1
# 6                 3          6     0.400000         4         2
# 7                 6          6     0.053097        17        14
# 8                16         13     0.031553        23        56
# 9                 0          0     0.000000         2         1
# 10                3          6     0.400000         4         2
# 11                6          6     0.053097        17        14
# 12               16         13     0.031553        23        56
# 13                0          0     0.000000         2         1
# 14                3          6     0.400000         4         2
# 15                6          6     0.053097        17        14
# 16               16         13     0.031553        23        56
# 17                2          0     0.000000         4         2
# 18               16         16     0.023495        45        94
# 19                2          8     0.800000         0         0
# 20                2          6     0.181818         3         7
#
# [6140 rows x 304 columns]

# %%
data_t = data_cl

# %%
# %store data_t
# Out:
# Stored 'data_t' (DataFrame)

# %% [markdown]
# ## TF-IDF matrix

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer

# %%
vectorizer = TfidfVectorizer(sublinear_tf=True, max_df=0.7)
X_t = vectorizer.fit_transform(data_t.text_str)

# %%
# %store X_t
# Out:
# Stored 'X_t' (csr_matrix)
