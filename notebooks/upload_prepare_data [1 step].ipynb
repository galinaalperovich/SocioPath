# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import os

# %%
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
# Out:
# /Users/jetbrains/miniconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
import paramiko

# %% [markdown]
# ### Upload new data from MetaCentrum

# %%
def load_remote_data():
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh.connect('skirit.metacentrum.cz', username='shchegal', password='Intend1@12')
    local_dir = 'data_parsed'
    local_files = os.listdir(local_dir)
    remote_dir = '/storage/brno2/home/shchegal/Diploma/parser/data_parsed'
    sftp = ssh.open_sftp()
    dir_items = sftp.listdir_attr(remote_dir)
    for item in dir_items:
        file_name = item.filename
        if item.filename not in local_files:
            local_path = os.path.join(local_dir, file_name)
            remote_path = remote_dir + '/' + file_name
            sftp.get(remote_path, local_path)

# %%
# Do it only if you have a new data
load_remote_data()

# %% [markdown]
# ### Data loading and first cleaning

# %%
# DATA_PATH = '/Users/jetbrains/Yandex.Disk.localized/Diploma/data_parsed/'
DIR = '/Users/jetbrains/Yandex.Disk.localized/Diploma/DATA_DIPLOMA'
DATA_PATH_REMOTE = DIR + '/data_parsed/'
# files = os.listdir(DATA_PATH)[1:]
files_remote = os.listdir(DATA_PATH_REMOTE)[1:]

# %%
with open(DIR + "/DATA.csv", "wb") as outfile:
#     for f in files:
#         with open(DATA_PATH + f, "rb") as infile:
#             outfile.write(infile.read())
    for f in files_remote:
        with open(DATA_PATH_REMOTE + f, "rb") as infile:
            outfile.write(infile.read())

# %%
data_from_many = pd.read_csv(DIR + '/DATA.csv', delimiter='\t')

# %%
data_from_many.head()
# Out:
#             https://oppex.com/electrical/bg/burgas\n       name  \
# 0  http://www.blu.fm/events/54114-Klubnacht-2016-...       name
# 1  http://www.blu.fm/events/54114-Klubnacht-2016-...  startDate
# 2  http://www.blu.fm/events/54114-Klubnacht-2016-...   location
# 3  http://www.blu.fm/events/54114-Klubnacht-2016-...   location
# 4  http://www.blu.fm/events/54114-Klubnacht-2016-...  startDate
#
#                                     School furniture   0  2086  24  356  \
# 0                                                NaN   0     0   0    0
# 1                                   02.04.2016 23:59   5   342  16  110
# 2  Berghain                                      ...   5   362  36  390
# 3  StandortBerghain                              ...  29   554  73  342
# 4                                   02.04.2016 23:59   5   342  16  110
#
#   header Unnamed: 8  2   ...   nowrap.1  single none.52 stretch.5  auto.49  \
# 0   meta        NaN  2   ...     normal  single    none   stretch     auto
# 1   time        NaN  2   ...     normal  single    none   stretch     auto
# 2      p        NaN  2   ...     normal  single    none   stretch     auto
# 3      p        NaN  7   ...     normal  single    none   stretch     auto
# 4   time        NaN  2   ...     normal  single    none   stretch     auto
#
#   auto.50 none.53 none.54 1.11 auto.51
# 0    auto    none    none    1    auto
# 1    auto    none    none    1    auto
# 2    auto    none    none    1    auto
# 3    auto    none    none    1    auto
# 4    auto    none    none    1    auto
#
# [5 rows x 297 columns]

# %%
# without id
data1 = pd.read_csv('/Users/jetbrains/PycharmProjects/SocioPath/data/data.csv', )

# with id, filtered type
data2 = pd.read_csv('/Users/jetbrains/PycharmProjects/SocioPath/data/data1.csv')
data3 = pd.read_csv('/Users/jetbrains/PycharmProjects/SocioPath/data/data2.csv')
data2 = data2.drop('id', 1)
data3 = data3.drop('id', 1)
data_from_first = pd.concat((data1, data2, data3), axis=0)
data_from_first.head(50)
# Out:
#                                                   url    meta_name  \
# 0   http://2016.election-polls.org/President/Democ...    startDate
# 1   http://2016.election-polls.org/President/Democ...      endDate
# 2   http://2016.election-polls.org/President/Democ...         name
# 3   http://2016.election-polls.org/President/Democ...      address
# 4   http://2016.election-polls.org/President/Democ...     attendee
# 5   http://2016.election-polls.org/President/Democ...    attendees
# 6   http://2016.election-polls.org/President/Democ...     attendee
# 7   http://2016.election-polls.org/President/Democ...    attendees
# 8   http://2016.election-polls.org/President/Democ...     attendee
# 9   http://2016.election-polls.org/President/Democ...     attendee
# 10  http://2016.election-polls.org/President/Democ...    attendees
# 11  http://2016.election-polls.org/President/Democ...     attendee
# 12  http://2012.republican-candidates.org/Palin/Is...          url
# 13  http://2012.republican-candidates.org/Palin/Is...         name
# 14  http://2012.republican-candidates.org/Palin/Is...    startDate
# 15  http://advantagenews.com/events/mississippi-va...         name
# 16  http://advantagenews.com/events/mississippi-va...    startDate
# 17  http://advantagenews.com/events/mississippi-va...      endDate
# 18  http://advantagenews.com/events/mississippi-va...     location
# 19  http://advantagenews.com/events/mississippi-va...     location
# 20  http://advantagenews.com/events/mississippi-va...    startDate
# 21  http://advantagenews.com/events/mississippi-va...      endDate
# 22  http://advantagenews.com/events/elder-abuse-pr...         name
# 23  http://advantagenews.com/events/elder-abuse-pr...    startDate
# 24  http://advantagenews.com/events/elder-abuse-pr...      endDate
# 25  http://advantagenews.com/events/elder-abuse-pr...     location
# 26  http://advantagenews.com/events/elder-abuse-pr...     location
# 27  http://advantagenews.com/events/elder-abuse-pr...    startDate
# 28  http://advantagenews.com/events/elder-abuse-pr...      endDate
# 29  http://advantagenews.com/news/police-appeal-fo...          url
# 30  http://advantagenews.com/news/police-appeal-fo...         name
# 31  http://advantagenews.com/news/police-appeal-fo...    startDate
# 32  http://advantagenews.com/news/police-appeal-fo...      endDate
# 33  http://advantagenews.com/news/police-appeal-fo...     location
# 34    http://animecons.com/events/info.shtml/4056\r\n    startDate
# 35    http://animecons.com/events/info.shtml/4056\r\n      endDate
# 36    http://animecons.com/events/info.shtml/4056\r\n         name
# 37    http://animecons.com/events/info.shtml/4056\r\n        image
# 38    http://animecons.com/events/info.shtml/4056\r\n     location
# 39    http://animecons.com/events/info.shtml/4056\r\n  description
# 40  http://austin.culturemap.com/search/?q=Jessica...    startDate
# 41  http://austin.culturemap.com/search/?q=Jessica...          url
# 42  http://austin.culturemap.com/search/?q=Jessica...          url
# 43                                                url    meta_name
# 44                                                url    meta_name
# 45  http://business.kittitascountychamber.com/even...         name
# 46  http://business.kittitascountychamber.com/even...    startDate
# 47  http://business.kittitascountychamber.com/even...    startDate
# 48  http://business.kittitascountychamber.com/even...      endDate
# 49  http://business.kittitascountychamber.com/even...  description
#
#                                                  text  x_coords  y_coords  \
# 0                                                 NaN         0         0
# 1                                                 NaN         0         0
# 2            The Economist / YouGov presidential poll         4       465
# 3                                          Nationwide       298       466
# 4                                     Hillary Clinton        72       953
# 5                                                 NaN        72       798
# 6                                      Bernie Sanders        72       823
# 7                                                 NaN        72       798
# 8                                           Undecided        72      1018
# 9                                     Martin O'Malley        72       953
# 10                                                NaN        72       993
# 11                                              Other        72      1083
# 12                         2016 Presidential Election       192       202
# 13                         2016 Presidential Election       192       202
# 14                                                NaN         0         0
# 15                                                NaN         0         0
# 16                              Mar 25, 2015 10:00 AM        20       766
# 17                                            4:00 PM       175       766
# 18  SIUe Morris Center                            ...        20       651
# 19  LocationSIUe Morris Center                    ...        20       416
# 20                              Mar 25, 2015 10:00 AM        20       766
# 21                                            4:00 PM       175       392
# 22                                                NaN         0         0
# 23                               Aug 19, 2016 1:30 PM        20       392
# 24                                            3:30 PM       168       934
# 25  Senior Services Plus                          ...        20       416
# 26  LocationSenior Services Plus                  ...        20       819
# 27                               Aug 19, 2016 1:30 PM        20       934
# 28                                            3:30 PM       168       392
# 29                                           Pinochle         0         0
# 30                                           Pinochle         0         0
# 31                               Oct 2, 2017 12:00 PM         0         0
# 32                                            3:00 PM         0         0
# 33                       Main Street Community Center         0         0
# 34                                                NaN         0         0
# 35                                                NaN         0         0
# 36                                         FANdom Con        51       318
# 37                                                NaN         0         0
# 38    University of West Florida CommonsPensacola, FL        51       367
# 39  Located in Pensacola Florida, FANdom Con is a ...        51       447
# 40                                                NaN         0         0
# 41                                                NaN       112      1072
# 42      Action Pack presents The Xmas Pops Sing-along        -5      1051
# 43                                               text  x_coords  y_coords
# 44                                               text  x_coords  y_coords
# 45                  ?Django Unchained? Film Screening        15       305
# 46                                     April 15, 2014        78       560
# 47                                            6:00 PM        82       602
# 48                                        8:00 PM PDT       169       602
# 49  Tuesday, April 15 at 6 p.m. Black Hall 151 Fre...        15       667
#
#     block_height  block_width   tag  num_child  num_siblings  \
# 0              0            0  meta          0             3
# 1              0            0  meta          0             3
# 2             16          276  span          0             5
# 3             15           64  span          0             5
# 4             15           70  span          1             1
# 5              0            0  span          0             1
# 6             15          111  span          1             1
# 7              0            0  span          0             1
# 8             15          121  span          1             1
# 9             15           70  span          1             1
# 10             0            0  span          0             1
# 11            15           38  span          1             1
# 12            15          150     a          1             9
# 13            15          150  span          0             1
# 14             0            0  meta          0             9
# 15             0            0  meta          0             2
# 16            15          136  time          0             3
# 17            15           48  time          0             3
# 18            51          360     p          5             7
# 19            34          360     p          3             2
# 20            15          136  time          0             3
# 21            15           48  time          0             3
# 22             0            0  meta        NaN             2
# 23            15          129  time        NaN             3
# 24            15           48  time        NaN             3
# 25            34          360     p        NaN             2
# 26            51          360     p        NaN             7
# 27            15          129  time        NaN             3
# 28            15           48  time        NaN             3
# 29             0            0     a        NaN             4
# 30             0            0  span        NaN             1
# 31             0            0  time        NaN             2
# 32             0            0  time        NaN             2
# 33             0            0     p        NaN             4
# 34             0            0  meta        NaN            11
# 35             0            0  meta        NaN            11
# 36            16          423    h1        NaN            11
# 37             0            0  meta        NaN            11
# 38            31          423  span        NaN            11
# 39            78          414  span        NaN             3
# 40             0            0  meta        NaN             2
# 41            32          277     a        NaN             4
# 42            87          102     a        NaN             2
# 43  block_height  block_width   tag  num_child  num_siblings
# 44  block_height  block_width   tag  num_child  num_siblings
# 45            72          370    h1        NaN             1
# 46            21          117  span        NaN             1
# 47            21           70  span        NaN             2
# 48            21          113  span        NaN             2
# 49           408          370   div        NaN             1
#
#            ...           white-space   -webkit-box-lines  \
# 0          ...                     0            baseline
# 1          ...                     0            baseline
# 2          ...                     0            baseline
# 3          ...                     0            baseline
# 4          ...                     0            baseline
# 5          ...                     0            baseline
# 6          ...                     0            baseline
# 7          ...                     0            baseline
# 8          ...                     0            baseline
# 9          ...                     0            baseline
# 10         ...                     0            baseline
# 11         ...                     0            baseline
# 12         ...                     0            baseline
# 13         ...                     0            baseline
# 14         ...                     0            baseline
# 15         ...                     0            baseline
# 16         ...                     0            baseline
# 17         ...                     0            baseline
# 18         ...                     0            baseline
# 19         ...                     0            baseline
# 20         ...                     0            baseline
# 21         ...                     0            baseline
# 22         ...          rgb(0, 0, 0)                auto
# 23         ...          rgb(0, 0, 0)                auto
# 24         ...          rgb(0, 0, 0)                auto
# 25         ...          rgb(0, 0, 0)                auto
# 26         ...          rgb(0, 0, 0)                auto
# 27         ...          rgb(0, 0, 0)                auto
# 28         ...          rgb(0, 0, 0)                auto
# 29         ...          rgb(0, 0, 0)                auto
# 30         ...          rgb(0, 0, 0)                auto
# 31         ...          rgb(0, 0, 0)                auto
# 32         ...          rgb(0, 0, 0)                auto
# 33         ...          rgb(0, 0, 0)                auto
# 34         ...          rgb(0, 0, 0)                auto
# 35         ...          rgb(0, 0, 0)                auto
# 36         ...          rgb(0, 0, 0)                auto
# 37         ...          rgb(0, 0, 0)                auto
# 38         ...          rgb(0, 0, 0)                auto
# 39         ...          rgb(0, 0, 0)                auto
# 40         ...          rgb(0, 0, 0)                auto
# 41         ...          rgb(0, 0, 0)                auto
# 42         ...          rgb(0, 0, 0)                auto
# 43         ...           white-space   -webkit-box-lines
# 44         ...           white-space   -webkit-box-lines
# 45         ...                  none  rgb(114, 143, 186)
# 46         ...                  none     rgb(63, 63, 63)
# 47         ...                  none     rgb(63, 63, 63)
# 48         ...                  none     rgb(63, 63, 63)
# 49         ...                  none     rgb(63, 63, 63)
#
#     -webkit-animation-name  -webkit-align-items  page-break-inside  \
# 0                     auto               normal               none
# 1                     auto               normal               none
# 2                     auto               normal               none
# 3                     auto               normal               none
# 4                     auto               normal               none
# 5                     auto               normal               none
# 6                     auto               normal               none
# 7                     auto               normal               none
# 8                     auto               normal               none
# 9                     auto               normal               none
# 10                    auto               normal               none
# 11                    auto               normal               none
# 12                    auto               normal               none
# 13                    auto               normal               none
# 14                    auto               normal               none
# 15                    auto               normal               none
# 16                    auto               normal               none
# 17                    auto               normal               none
# 18                    auto               normal               none
# 19                    auto               normal               none
# 20                    auto               normal               none
# 21                    auto               normal               none
# 22                    ease                 auto                  1
# 23                    ease                 auto                  1
# 24                    ease                 auto                  1
# 25                    ease                 auto                  1
# 26                    ease                 auto                  1
# 27                    ease                 auto                  1
# 28                    ease                 auto                  1
# 29                    ease                 auto                  1
# 30                    ease                 auto                  1
# 31                    ease                 auto                  1
# 32                    ease                 auto                  1
# 33                    ease                 auto                  1
# 34                    ease                 auto                  1
# 35                    ease                 auto                  1
# 36                    ease                 auto                  1
# 37                    ease                 auto                  1
# 38                    ease                 auto                  1
# 39                    ease                 auto                  1
# 40                    ease                 auto                  1
# 41                    ease                 auto                  1
# 42                    ease                 auto                  1
# 43  -webkit-animation-name  -webkit-align-items  page-break-inside
# 44  -webkit-animation-name  -webkit-align-items  page-break-inside
# 45                    auto                   0s              0% 0%
# 46                    auto                   0s              0% 0%
# 47                    auto                   0s              0% 0%
# 48                    auto                   0s              0% 0%
# 49                    auto                   0s              0% 0%
#
#     -webkit-grid-auto-rows  -webkit-clip-path  max-height  stroke-width  \
# 0                     none            nonzero        auto             1
# 1                     none            nonzero        auto             1
# 2                     none            nonzero        auto             1
# 3                     none            nonzero        auto             1
# 4                     none            nonzero        auto             1
# 5                     none            nonzero        auto             1
# 6                     none            nonzero        auto             1
# 7                     none            nonzero        auto             1
# 8                     none            nonzero        auto             1
# 9                     none            nonzero        auto             1
# 10                    none            nonzero        auto             1
# 11                    none            nonzero        auto             1
# 12                    none            nonzero        auto             1
# 13                    none            nonzero        auto             1
# 14                    none            nonzero        auto             1
# 15                    none            nonzero        auto             1
# 16                    none            nonzero        auto             1
# 17                    none            nonzero        auto             1
# 18                    none            nonzero        auto             1
# 19                    none            nonzero        auto             1
# 20                    none            nonzero        auto             1
# 21                    none            nonzero        auto             1
# 22                     ltr                0px        none    border-box
# 23                     ltr                0px        none    border-box
# 24                     ltr                0px        none    border-box
# 25                     ltr                0px        none    border-box
# 26                     ltr                0px        none    border-box
# 27                     ltr                0px        none    border-box
# 28                     ltr                0px        none    border-box
# 29                     ltr                0px        none    border-box
# 30                     ltr                0px        none    border-box
# 31                     ltr                0px        none    border-box
# 32                     ltr                0px        none    border-box
# 33                     ltr                0px        none    border-box
# 34                     ltr                0px        none    border-box
# 35                     ltr                0px        none    border-box
# 36                     ltr                0px        none    border-box
# 37                     ltr                0px        none    border-box
# 38                     ltr                0px        none    border-box
# 39                     ltr                0px        none    border-box
# 40                     ltr                0px        none    border-box
# 41                     ltr                0px        none    border-box
# 42                     ltr                0px        none    border-box
# 43  -webkit-grid-auto-rows  -webkit-clip-path  max-height  stroke-width
# 44  -webkit-grid-auto-rows  -webkit-clip-path  max-height  stroke-width
# 45              horizontal               none        none      no-limit
# 46              horizontal               none        none      no-limit
# 47              horizontal               none        none      no-limit
# 48              horizontal               none        none      no-limit
# 49              horizontal               none        none      no-limit
#
#     buffered-rendering
# 0                 auto
# 1                 auto
# 2                 auto
# 3                 auto
# 4                 auto
# 5                 auto
# 6                 auto
# 7                 auto
# 8                 auto
# 9                 auto
# 10                auto
# 11                auto
# 12                auto
# 13                auto
# 14                auto
# 15                auto
# 16                auto
# 17                auto
# 18                auto
# 19                auto
# 20                auto
# 21                auto
# 22                   0
# 23                   0
# 24                   0
# 25                   0
# 26                   0
# 27                   0
# 28                   0
# 29                   0
# 30                   0
# 31                   0
# 32                   0
# 33                   0
# 34                   0
# 35                   0
# 36                   0
# 37                   0
# 38                   0
# 39                   0
# 40                   0
# 41                   0
# 42                   0
# 43  buffered-rendering
# 44  buffered-rendering
# 45                flat
# 46                flat
# 47                flat
# 48                flat
# 49                flat
#
# [50 rows x 297 columns]

# %%
data_from_many.columns = data_from_first.columns

# %%
# data = pd.concat((data_from_many, data_from_first), axis=0)
data = data_from_many

# %%
data.shape
# Out:
# (150388, 297)

# %%
data.url.unique().size
# Out:
# 53824

# %%
# %store data
# Out:
# Stored 'data' (DataFrame)
