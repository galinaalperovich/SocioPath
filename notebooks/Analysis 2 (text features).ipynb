# %%
from utils_all import *
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.manifold import TSNE
import seaborn as sns
# %matplotlib inline
import inspect
from sklearn.decomposition import IncrementalPCA
from sklearn import manifold

# %%
# %store -r data
# %store -r df_1_final

# %%
data = df_1_final

# %%
data_cl = clean_df(data)

# %%
len(list(filter(lambda x: x,data_cl.text.isnull())))
# Out:
# 65

# %%
data_cl.shape
# Out:
# (6782, 299)

# %% [markdown]
# First of all, let's create several obviouse features:
# - len of the text
# - number of punctuation
# - number of digits
# - #numbers/len
# - number of upper case
#
# Links: https://www.quora.com/Natural-Language-Processing-What-are-the-possible-features-that-can-be-extracted-from-text

# %%
import re
import string

# %%
data_cl['text_str'] = data_cl.text.apply(str).replace('nan','')

# %%
data_cl['text_len'] = data_cl.text_str.apply(len)

# %%
count = lambda l1, l2: len(list(filter(lambda c: c in l2, l1)))

# %%
data_cl['num_punctuation'] = data_cl.text_str.apply(lambda x: count(x, string.punctuation))

# %%
data_cl['num_digits'] = data_cl.text_str.apply(lambda x: count(x, string.digits))

# %%
data_cl['digits_share'] = data_cl.num_digits/data_cl.text_len

# %%
data_cl['num_upper'] = data_cl.text_str.apply(lambda x: count(x, string.ascii_uppercase))

# %%
data_cl['num_upper'] = data_cl.text_str.apply(lambda x: count(x, string.whitespace))

# %%
data_cl
# Out:
#                                                       url    meta_name  \
# 103     http://www.livenation.com/events/155446-oct-26...    startDate
# 104     http://www.livenation.com/events/213114-jan-31...    startDate
# 105     http://www.livenation.com/events/373699-oct-24...    startDate
# 139     http://mysunshinecoast.com.au/events/events-di...         name
# 140     http://mysunshinecoast.com.au/events/events-di...    startDate
# 141     http://mysunshinecoast.com.au/events/events-di...     location
# 205     http://mysunshinecoast.com.au/events/events-di...         name
# 206     http://mysunshinecoast.com.au/events/events-di...    startDate
# 207     http://mysunshinecoast.com.au/events/events-di...     location
# 228     http://mysunshinecoast.com.au/events/events-di...         name
# 229     http://mysunshinecoast.com.au/events/events-di...    startDate
# 230     http://mysunshinecoast.com.au/events/events-di...     location
# 231     http://mysunshinecoast.com.au/events/events-di...         name
# 232     http://mysunshinecoast.com.au/events/events-di...    startDate
# 233     http://mysunshinecoast.com.au/events/events-di...     location
# 238     http://rockeros.net/eventos/233-noches-rockera...         name
# 239     http://rockeros.net/eventos/233-noches-rockera...    startDate
# 240     http://rockeros.net/eventos/233-noches-rockera...     location
# 294     http://hooversun.com/opinion/mayors-note/warme...         name
# 295     http://hooversun.com/opinion/mayors-note/warme...    startDate
# 296     http://hooversun.com/opinion/mayors-note/warme...     location
# 304     http://wku.edu/events/index.php?eventid=18139&...         name
# 305     http://wku.edu/events/index.php?eventid=18139&...    startDate
# 306     http://wku.edu/events/index.php?eventid=18139&...     location
# 339     http://www.bucuresteni.ro/info/cinema/t--eveni...         name
# 340     http://www.bucuresteni.ro/info/cinema/t--eveni...  description
# 341     http://www.bucuresteni.ro/info/cinema/t--eveni...    startDate
# 342     http://www.bucuresteni.ro/info/cinema/t--eveni...     location
# 381     http://www.livenation.com/events/243727-aug-17...    startDate
# 382     http://mysunshinecoast.com.au/events/events-di...         name
# ...                                                   ...          ...
# 148640  https://www.samhealth.org/health-services/clas...    startDate
# 148753  http://www.chestercounty.com/events/16367/cook...         name
# 148754  http://www.chestercounty.com/events/16367/cook...     location
# 148756  http://www.chestercounty.com/events/16367/cook...    startDate
# 148757  http://www.chestercounty.com/events/16367/cook...  description
# 148867  http://www.p2000zhz-rr.nl/p2000-brandweer-flev...    startDate
# 148869  http://www.p2000zhz-rr.nl/p2000-brandweer-flev...  description
# 149296  http://www.visitbratislava.com/events/united-m...  description
# 149297  http://www.visitbratislava.com/events/united-m...    startDate
# 149691  http://www.okticket.de/?veranstalter_user_id=1...    startDate
# 149692  http://www.okticket.de/?veranstalter_user_id=1...         name
# 149693  http://www.okticket.de/?veranstalter_user_id=1...     location
# 149728             https://www.oclc.org/fr-CA/events.html    startDate
# 149729             https://www.oclc.org/fr-CA/events.html         name
# 149799         http://www.resultados-futbol.com/marruecos         name
# 149800         http://www.resultados-futbol.com/marruecos    startDate
# 149801         http://www.resultados-futbol.com/marruecos     location
# 149842  http://www.paris-friendly.fr/idee-cadeau-solid...    startDate
# 149852  http://www.woodworkingnetwork.com/woodworking-...  description
# 149853  http://www.woodworkingnetwork.com/woodworking-...    startDate
# 149854  http://www.woodworkingnetwork.com/woodworking-...     location
# 149972  https://www.racemine.com/evolutionmarketingcr/...         name
# 149973  https://www.racemine.com/evolutionmarketingcr/...    startDate
# 150036  https://www.bethel.edu/events/2018/academic-da...    startDate
# 150037  https://www.bethel.edu/events/2018/academic-da...  description
# 150052  http://business.bayfield.org/events/search?fro...         name
# 150053  http://business.bayfield.org/events/search?fro...    startDate
# 150320  https://www.homeinstead.com/106/calendar/carin...    startDate
# 150347  http://mspmag.com/locations/cowles-center-danc...         name
# 150348  http://mspmag.com/locations/cowles-center-danc...    startDate
#
#                                                      text  x_coords  y_coords  \
# 103                     Friday Oct 26, 2012at09:00 PM CDT        51       481
# 104                   Thursday Jan 31, 2013at07:30 PM EST        51       717
# 105                     Friday Oct 24, 2014at08:00 PM CDT        51       862
# 139                             DeepBlue Winter Workshops        69        38
# 140                               Thursday 10th July 2014       126       399
# 141     Nambour Civic Centre,\r    \r      Nambour\r  ...        69       467
# 205               Headspace: meditation for study success        69        38
# 206                           Wednesday 12th October 2011        69       399
# 207     Nambour library,\r    \r      Nambour\r      4...       149       467
# 228                                African Dance Workshop        69        38
# 229                            Friday 19th September 2008       117       373
# 230     Noosa Library,\r    \r      Not Assigned\r    ...        69       407
# 231       Blue House Eco-renovating and Workshop Open Day        69        38
# 232                                 Sunday 21st June 2009       117       399
# 233     Yandina Community Gardens,\r    \r      Yandin...        69       433
# 238       Noches Rockeras At The House Of Blues San Diego       220       345
# 239                            Viernes 14 De Agosto, 2009       507       378
# 240     House Of Blues1055 5th AvenueSan DiegoCaliforn...       220       500
# 294                                       High Country 5K        20      3433
# 295                                   Apr 8, 2017 8:00 AM        20      3452
# 296                           Shades Crest Baptist Church        20      3471
# 304                 Matthew Carmichael, Saxophone Recital        15       249
# 305                             Tuesday, April 22nd, 2014        62       303
# 306               Ivan Wilson Center-Fine Arts - FAC 0189        89       343
# 339                              Vicky Cristina Barcelona        15      3824
# 340                                            Joi: 20:15        15      3896
# 341                                 Vineri 27 martie 2009        31      3969
# 342                                     Movieplex Romania       287      3968
# 381                   Saturday Aug 17, 2013at08:00 PM EDT        51       890
# 382     Book launch of 'Alan Pearson: Expressionist Po...        69        38
# ...                                                   ...       ...       ...
# 148640                                                 03       144       611
# 148753          Cooking Demo and Tasting with The Mildred         8       843
# 148754                                   Wayne Art Center        63      1368
# 148756                                   October  9, 2013        63      1396
# 148757  Tastes of the Town, our popular restaurant ser...         8      1699
# 148867                                                NaN        22      8919
# 148869                                                NaN       107      8919
# 149296  Five years ago it was just an idea to make wor...         8       340
# 149297                                        6. Mar 2015        90       806
# 149691                       So 16. April 2017\r21:00 Uhr       137       338
# 149692                         EiEiEi - Die Ostersause #4       137       358
# 149693                              Weiden, Jugendzentrum       137       396
# 149728                                        17 mai 2017       100      4611
# 149729  Managing your e-resources and licenses: A demo...       100      4635
# 149799         JSK Chabab Kasba Tadla vs Wydad Casablanca       875      3844
# 149800                                    16 Abr 17 17:30      1020      4065
# 149801                                    Stade Municipal       875      4415
# 149842                           du jeudi 31 janvier 2013        20       333
# 149852                                   About the Event:        45       638
# 149853                   September 16, 2013 | 3:00 am EDT        60      1401
# 149854  Venue                                      Ogd...        60      1582
# 149972  Event Details for\r                           ...        15       197
# 149973                   Sunday, August 17, 2014 12:00 AM        15       254
# 150036                                   January 25, 2018       138       211
# 150037  Last day of classes for students enrolled in t...        32       329
# 150052                 Glassblowing at Oulu Glass Gallery        80      4804
# 150053                                Friday May 29, 2015        80      4848
# 150320                                 September 07, 2016        20       603
# 150347  Zorongo Flamenco Dance Theatre together with F...        12      1730
# 150348                                       Apr 21, 2017        12      1813
#
#         block_height  block_width      tag num_child  num_siblings    ...     \
# 103               22           75     span       NaN             4    ...
# 104               22           86     span       NaN             4    ...
# 105               22           83     span       NaN             4    ...
# 139               55          193     span       NaN             1    ...
# 140               21          207     time       NaN             1    ...
# 141               55          274     span       NaN             1    ...
# 205               55          295     span       NaN             1    ...
# 206               55          269     time       NaN             1    ...
# 207               21          230     span       NaN             1    ...
# 228               29          278     span       NaN             1    ...
# 229               21          244     time       NaN             1    ...
# 230               55          240     span       NaN             1    ...
# 231               55          307     span       NaN             1    ...
# 232               21          197     time       NaN             1    ...
# 233               55          256     span       NaN             1    ...
# 238               21          530       h1       NaN            24    ...
# 239               14          192     span       NaN             1    ...
# 240               84          530        p       NaN            24    ...
# 294               15          120     span       NaN             1    ...
# 295               16          141     time       NaN             2    ...
# 296               22          360        p       NaN             4    ...
# 304               19          355     span       NaN             1    ...
# 305               14          161     span       NaN            12    ...
# 306               14          242     span       NaN            12    ...
# 339               57          147     span      None             1    ...
# 340               32          370       li      None             5    ...
# 341               18          138     span      None             2    ...
# 342               42           82      div      None             1    ...
# 381               22           83     span      None             4    ...
# 382               81          305     span       NaN             1    ...
# ...              ...          ...      ...       ...           ...    ...
# 148640            23           74     span      None             3    ...
# 148753           114          337     span      None             3    ...
# 148754            19          165   strong      None             2    ...
# 148756            19          148     span      None             1    ...
# 148757           152          384        p      None             4    ...
# 148867            14           70      div      None             4    ...
# 148869          1400          950      div      None             4    ...
# 149296           281          384      div      None             2    ...
# 149297            18           84     span      None             3    ...
# 149691            17          173     span      None             2    ...
# 149692            22          202     span      None             1    ...
# 149693            12          109     span      None             1    ...
# 149728            21          255        p      None             4    ...
# 149729           105          255       h1      None             4    ...
# 149799            30          241        b      None             1    ...
# 149800            15          145     span      None             3    ...
# 149801            16          145      div      None             3    ...
# 149842            14          165     time      None             2    ...
# 149852           759          310      div      None             3    ...
# 149853            56          278     time      None             4    ...
# 149854           148          280  address      None             2    ...
# 149972            47          370       h1      None             5    ...
# 149973            27          370       h4      None             5    ...
# 150036            16          121     span      None             2    ...
# 150037            67          329     span      None             1    ...
# 150052            38          240      div      None             4    ...
# 150053            15          127     span      None             1    ...
# 150320            30          245     span      None             1    ...
# 150347            74          324     span      None             1    ...
# 150348            16           92     time      None             2    ...
#
#        buffered-rendering                  domain keep  \
# 103                  auto          livenation.com    1
# 104                  auto          livenation.com    1
# 105                  auto          livenation.com    1
# 139                  auto  mysunshinecoast.com.au    1
# 140                  auto  mysunshinecoast.com.au    1
# 141                  auto  mysunshinecoast.com.au    1
# 205                  auto  mysunshinecoast.com.au    1
# 206                  auto  mysunshinecoast.com.au    1
# 207                  auto  mysunshinecoast.com.au    1
# 228                  auto  mysunshinecoast.com.au    1
# 229                  auto  mysunshinecoast.com.au    1
# 230                  auto  mysunshinecoast.com.au    1
# 231                  auto  mysunshinecoast.com.au    1
# 232                  auto  mysunshinecoast.com.au    1
# 233                  auto  mysunshinecoast.com.au    1
# 238                  auto            rockeros.net    1
# 239                  auto            rockeros.net    1
# 240                  auto            rockeros.net    1
# 294                  auto           hooversun.com    1
# 295                  auto           hooversun.com    1
# 296                  auto           hooversun.com    1
# 304                  auto                 wku.edu    1
# 305                  auto                 wku.edu    1
# 306                  auto                 wku.edu    1
# 339                  auto          bucuresteni.ro    1
# 340                  auto          bucuresteni.ro    1
# 341                  auto          bucuresteni.ro    1
# 342                  auto          bucuresteni.ro    1
# 381                  auto          livenation.com    1
# 382                  auto  mysunshinecoast.com.au    1
# ...                   ...                     ...  ...
# 148640               auto           samhealth.org    1
# 148753               auto       chestercounty.com    1
# 148754               auto       chestercounty.com    1
# 148756               auto       chestercounty.com    1
# 148757               auto       chestercounty.com    1
# 148867               auto          p2000zhz-rr.nl    1
# 148869               auto          p2000zhz-rr.nl    1
# 149296               auto     visitbratislava.com    1
# 149297               auto     visitbratislava.com    1
# 149691               auto             okticket.de    1
# 149692               auto             okticket.de    1
# 149693               auto             okticket.de    1
# 149728               auto                oclc.org    1
# 149729               auto                oclc.org    1
# 149799               auto   resultados-futbol.com    1
# 149800               auto   resultados-futbol.com    1
# 149801               auto   resultados-futbol.com    1
# 149842               auto       paris-friendly.fr    1
# 149852               auto  woodworkingnetwork.com    1
# 149853               auto  woodworkingnetwork.com    1
# 149854               auto  woodworkingnetwork.com    1
# 149972               auto            racemine.com    1
# 149973               auto            racemine.com    1
# 150036               auto              bethel.edu    1
# 150037               auto              bethel.edu    1
# 150052               auto   business.bayfield.org    1
# 150053               auto   business.bayfield.org    1
# 150320               auto         homeinstead.com    1
# 150347               auto              mspmag.com    1
# 150348               auto              mspmag.com    1
#
#                                                  text_str  text_len  \
# 103                     Friday Oct 26, 2012at09:00 PM CDT        33
# 104                   Thursday Jan 31, 2013at07:30 PM EST        35
# 105                     Friday Oct 24, 2014at08:00 PM CDT        33
# 139                             DeepBlue Winter Workshops        25
# 140                               Thursday 10th July 2014        23
# 141     Nambour Civic Centre,\r    \r      Nambour\r  ...        68
# 205               Headspace: meditation for study success        39
# 206                           Wednesday 12th October 2011        27
# 207     Nambour library,\r    \r      Nambour\r      4...        63
# 228                                African Dance Workshop        22
# 229                            Friday 19th September 2008        26
# 230     Noosa Library,\r    \r      Not Assigned\r    ...        66
# 231       Blue House Eco-renovating and Workshop Open Day        47
# 232                                 Sunday 21st June 2009        21
# 233     Yandina Community Gardens,\r    \r      Yandin...        73
# 238       Noches Rockeras At The House Of Blues San Diego        47
# 239                            Viernes 14 De Agosto, 2009        26
# 240     House Of Blues1055 5th AvenueSan DiegoCaliforn...        67
# 294                                       High Country 5K        15
# 295                                   Apr 8, 2017 8:00 AM        19
# 296                           Shades Crest Baptist Church        27
# 304                 Matthew Carmichael, Saxophone Recital        37
# 305                             Tuesday, April 22nd, 2014        25
# 306               Ivan Wilson Center-Fine Arts - FAC 0189        39
# 339                              Vicky Cristina Barcelona        24
# 340                                            Joi: 20:15        10
# 341                                 Vineri 27 martie 2009        21
# 342                                     Movieplex Romania        17
# 381                   Saturday Aug 17, 2013at08:00 PM EDT        35
# 382     Book launch of 'Alan Pearson: Expressionist Po...        72
# ...                                                   ...       ...
# 148640                                                 03         2
# 148753          Cooking Demo and Tasting with The Mildred        41
# 148754                                   Wayne Art Center        16
# 148756                                   October  9, 2013        16
# 148757  Tastes of the Town, our popular restaurant ser...       302
# 148867                                                            0
# 148869                                                            0
# 149296  Five years ago it was just an idea to make wor...       324
# 149297                                        6. Mar 2015        11
# 149691                       So 16. April 2017\r21:00 Uhr        27
# 149692                         EiEiEi - Die Ostersause #4        26
# 149693                              Weiden, Jugendzentrum        21
# 149728                                        17 mai 2017        11
# 149729  Managing your e-resources and licenses: A demo...        89
# 149799         JSK Chabab Kasba Tadla vs Wydad Casablanca        42
# 149800                                    16 Abr 17 17:30        15
# 149801                                    Stade Municipal        15
# 149842                           du jeudi 31 janvier 2013        24
# 149852                                   About the Event:        16
# 149853                   September 16, 2013 | 3:00 am EDT        32
# 149854  Venue                                      Ogd...       229
# 149972  Event Details for\r                           ...        67
# 149973                   Sunday, August 17, 2014 12:00 AM        32
# 150036                                   January 25, 2018        16
# 150037  Last day of classes for students enrolled in t...       108
# 150052                 Glassblowing at Oulu Glass Gallery        34
# 150053                                Friday May 29, 2015        19
# 150320                                 September 07, 2016        18
# 150347  Zorongo Flamenco Dance Theatre together with F...        93
# 150348                                       Apr 21, 2017        12
#
#        num_punctuation num_digits digits_share num_upper num_space
# 103                  2         10     0.303030         7         5
# 104                  2         10     0.285714         7         5
# 105                  2         10     0.303030         7         5
# 139                  0          0     0.000000         4         2
# 140                  0          6     0.260870         2         3
# 141                  1          4     0.058824         5        28
# 205                  1          0     0.000000         1         4
# 206                  0          6     0.222222         2         3
# 207                  1          4     0.063492         3        27
# 228                  0          0     0.000000         3         2
# 229                  0          6     0.230769         2         3
# 230                  1          4     0.060606         5        28
# 231                  1          0     0.000000         6         6
# 232                  0          6     0.285714         2         3
# 233                  1          4     0.054795         5        28
# 238                  0          0     0.000000         9         8
# 239                  1          6     0.230769         3         4
# 240                  0         10     0.149254         9         6
# 294                  0          1     0.066667         3         2
# 295                  2          8     0.421053         3         4
# 296                  0          0     0.000000         4         3
# 304                  1          0     0.000000         4         3
# 305                  2          6     0.240000         2         3
# 306                  2          4     0.102564         8         6
# 339                  0          0     0.000000         3         2
# 340                  2          4     0.400000         1         1
# 341                  0          6     0.285714         1         3
# 342                  0          0     0.000000         2         1
# 381                  2         10     0.285714         7         5
# 382                  3          0     0.000000         7         9
# ...                ...        ...          ...       ...       ...
# 148640               0          2     1.000000         0         0
# 148753               0          0     0.000000         5         6
# 148754               0          0     0.000000         3         2
# 148756               1          5     0.312500         1         3
# 148757              11          0     0.000000         9        43
# 148867               0          0          NaN         0         0
# 148869               0          0          NaN         0         0
# 149296               9          7     0.021605        11        53
# 149297               1          5     0.454545         1         2
# 149691               2         10     0.370370         3         5
# 149692               2          1     0.038462         5         4
# 149693               1          0     0.000000         2         1
# 149728               0          6     0.545455         0         2
# 149729               2          0     0.000000         6        10
# 149799               0          0     0.000000         8         6
# 149800               1          8     0.533333         1         3
# 149801               0          0     0.000000         2         1
# 149842               0          6     0.250000         0         4
# 149852               1          0     0.000000         2         2
# 149853               3          9     0.281250         4         6
# 149854               3          0     0.000000         9       185
# 149972               0          0     0.000000         4        40
# 149973               3         10     0.312500         4         5
# 150036               1          6     0.375000         1         2
# 150037               3          0     0.000000         9        18
# 150052               0          0     0.000000         4         4
# 150053               1          6     0.315789         2         3
# 150320               1          6     0.333333         1         2
# 150347               2          0     0.000000        11        14
# 150348               1          6     0.500000         1         2
#
# [6782 rows x 306 columns]

# %%
data_t = data_cl

# %%
# %store data_t
# Out:
# Stored 'data_t' (DataFrame)

# %% [markdown]
# ## TF-IDF matrix

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer

# %%
vectorizer = TfidfVectorizer(sublinear_tf=True, max_df=0.7)
X_t = vectorizer.fit_transform(data_t.text_str)

# %%
# %store X_t
# Out:
# Stored 'X_t' (csr_matrix)
